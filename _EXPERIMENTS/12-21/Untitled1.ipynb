# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import mahotas as mh

# %%
# !pip install pynrrd

# %%
import nrrd

# %%
# !pip install natsort

# %%
from natsort import natsorted

# %%
DATA_DIR = '/raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5'

# %%
all_images = []

# %%
len(os.listdir(DATA_DIR))
# Out:
# 117

# %%
img_names = os.listdir(DATA_DIR)

# %%
i_names_sorted = natsorted(img_names)

# %%
print(i_names_sorted)
# Out:
# ['.ipynb_checkpoints', 'a0.tif', 'a1.tif', 'a2.tif', 'a3.tif', 'a4.tif', 'a5.tif', 'a6.tif', 'a7.tif', 'a8.tif', 'a9.tif', 'a10.tif', 'a11.tif', 'a12.tif', 'a37.tif', 'a41.tif', 'a56.tif', 'a57.tif', 'a58.tif', 'a60.tif', 'a62.tif', 'a63.tif', 'a64.tif', 'a65.tif', 'a66.tif', 'a67.tif', 'a68.tif', 'a69.tif', 'a70.tif', 'a71.tif', 'a72.tif', 'a73.tif', 'a74.tif', 'a75.tif', 'a76.tif', 'a77.tif', 'a78.tif', 'a79.tif', 'a80.tif', 'a81.tif', 'a82.tif', 'a83.tif', 'a84.tif', 'a85.tif', 'a86.tif', 'a87.tif', 'a88.tif', 'a89.tif', 'a90.tif', 'a91.tif', 'a92.tif', 'a93.tif', 'a94.tif', 'a95.tif', 'a96.tif', 'a97.tif', 'a98.tif', 'a99.tif', 'a100.tif', 'a101.tif', 'a102.tif', 'a103.tif', 'a104.tif', 'a105.tif', 'a106.tif', 'a107.tif', 'a108.tif', 'a109.tif', 'a110.tif', 'a111.tif', 'a112.tif', 'a113.tif', 'a114.tif', 'a115.tif', 'a116.tif', 'a117.tif', 'a118.tif', 'a119.tif', 'a120.tif', 'a121.tif', 'a122.tif', 'a123.tif', 'a124.tif', 'a125.tif', 'a126.tif', 'a127.tif', 'a128.tif', 'a129.tif'
# ...

# %%
for i in i_names_sorted:
    if i.endswith('tif'):
        file_path = os.path.join(DATA_DIR, i)
        print(file_path)
        a = mh.imread(file_path)
        imshow(a)
        show()
        all_images.append(a)
# Out:
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a0.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a1.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a2.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a3.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a4.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a5.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a6.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a7.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a8.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a9.tif
# /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/good_5/a10.tif
# ...

# %%
len(all_images)
# Out:
# 122

# %%
all_image_np_array = np.array(all_images)

# %%
all_image_np_array.shape
# Out:
# (122, 500, 1500)

# %%
np.save(os.path.join(DATA_DIR, 'fly-1.npy'), all_image_np_array)

# %%
imshow(all_image_np_array[1])

# %%
nrrd.write(os.path.join(DATA_DIR ,'fly-1.nrrd'), all_image_np_array)
