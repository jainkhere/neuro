# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os, sys

# %%
mito_code = '/home/haehn/Projects/mitochondria/a-fully-supervised-unet/'
weights = os.path.join(mito_code, 'models/A100test/weights.26-0.36.hdf5')

# %%
sys.path.append(mito_code)
import data_management
from data_management import load_stack
from data_management import load_data

import interactive_plot

import metrics
from metrics import statistics
from metrics import confusion_matrix
from metrics import error_distribution
from metrics import error_borders
from metrics import PR_curve

import generator_extended

import unet
from unet import load_model_unet
from unet import predict_net
from unet import get_unet
from unet import train
from unet import execute_predict

# %%
import mahotas as mh

# %%
img = mh.imread('')
# TODO maybe invert the image

# %%
model = load_model_unet(weights)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-12-2d7a847a0417> in <module>
# ----> 1 load_model_unet(weights)
#
# ~/Projects/mitochondria/a-fully-supervised-unet/unet.py in load_model_unet(file, use_dice_loss, use_jaccard_loss, use_focal_loss)
#      13     if use_focal_loss:
#      14         cobj['keras_focal_loss'] = metrics.keras_focal_loss
# ---> 15     model = keras.models.load_model(file, custom_objects=cobj)
#      16     return model
#      17
#
# ~/miniconda3/envs/mito/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     182     if (h5py is not None and (
#     183         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 184       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     185
# ...

# %%
pred = predict_net(model, img)

# %%
imshow(pred)
